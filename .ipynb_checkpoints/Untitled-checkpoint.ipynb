# %% [markdown]
# Import all data and remove columns unable to be used in model
# Need to fist evaluate which columns will be useful

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

df_calendar = pd.read_csv(r'C:\Users\Scott\Desktop\Udacity Project\data\archive\calendar.csv')
df_listings = pd.read_csv(r'C:\Users\Scott\Desktop\Udacity Project\data\archive\listings.csv')
df_reviews = pd.read_csv(r'C:\Users\Scott\Desktop\Udacity Project\data\archive\reviews.csv')

#df_listings.head(30)
#print(df_listings.shape[0])
#print(df_listings.shape[1])

#print(set(df_listings.columns[np.sum(df_listings.isnull()) == 0]))

#Check into picture url
#print(np.max(df_listings['picture_url'].str.len()))

#Checking columns' counts
#list(df_listings.nunique())

#Removed columns (urls and high NaN columns)
df_listings_new = df_listings.drop(['listing_url','thumbnail_url','medium_url', \
                                    'picture_url','xl_picture_url','host_url', \
                                    'host_thumbnail_url','host_picture_url', \
                                     'square_feet','license','last_scraped'], axis =1)
#df_listings_new.info()

#Close look at columns with data type = object 
df_listings_new.select_dtypes(include = ['object'])

#Selection of small set of columns to determine appropriateness of using in model
#df_listings_new[['name','summary','space',len(['description']),'experiences_offered']]

#Mean of length of strings for 'Description' shows an average length of 870 chars 
#np.sum(df_listings_new['description'].str.len().mean())

#All rows from 'Description' with string length equal to the max, 1000 chars
#df_listings_new['description'].str.len()[df_listings_new['description'].str.len() == 1000]
# Out:
# <ipython-input-41-c17ca9fe63a0>:7: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                     name  \
# 0     Stylish Queen Anne Apartment
# 1     Bright & Airy Queen Anne Apartment
# ...                                  ...
# 3816  Amazing View with Modern Comfort!
# 3817  Large Lakefront Apartment
#
#                                                                                                                                                                                                                                                                                 summary  \
# 0     NaN
# ...

# %% [markdown]
# List of columns that appear to allow renters to type anything:
#
# 'summary', 'space', description, 'notes','name'
#
# These might be good columns to evaluate, to determine whether or not more decriptions provided by the renter correlates to better reviews, higher chance of being rented
